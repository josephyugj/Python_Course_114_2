# %% [markdown]
# # 第六章 串列(List)
# ## 6.1 認識串列
# ### 6.1.1 串列基本定義
# ### 程式實例 ch6_1.py: 定義串列同時列印，最後使用type()列出串列資料型態

# %%
#### ch6_1.py
james = [23, 19, 22, 31, 18]                # 定義james串列
print("列印james串列", james)
James = ['Lebron James',23, 19, 22, 31, 18] # 定義James串列
print("列印James串列", James)
fruits = ['apple', 'banana', 'orange']      # 定義fruits串列
print("列印fruits串列", fruits)
cfruits = ['蘋果', '香蕉', '橘子']          # 定義cfruits串列
print("列印cfruits串列", cfruits)
ielts = [5.5, 6.0, 6.5]                     # 定義IELTS成績串列
print("列印IELTS成績", ielts)
# 列出串列資料型態
print("串列james資料型態是: ",type(james))
# Out:
# 列印james串列 [23, 19, 22, 31, 18]
# 列印James串列 ['Lebron James', 23, 19, 22, 31, 18]
# 列印fruits串列 ['apple', 'banana', 'orange']
# 列印cfruits串列 ['蘋果', '香蕉', '橘子']
# 列印IELTS成績 [5.5, 6.0, 6.5]
# 串列james資料型態是:  <class 'list'>

# %% [markdown]
# ### 6.1.2 讀取串列元素
# ### 程式實例 ch6_2.py: 讀取串列元素的應用

# %%
# ch6_2.py
james = [23, 19, 22, 31, 18]                # 定義james串列
print("列印james第1場得分", james[0])
print("列印james第2場得分", james[1])
print("列印james第3場得分", james[2])
print("列印james第4場得分", james[3])
print("列印james第5場得分", james[4])
# Out:
# 列印james第1場得分 23
# 列印james第2場得分 19
# 列印james第3場得分 22
# 列印james第4場得分 31
# 列印james第5場得分 18

# %% [markdown]
# ### 程式實例 ch6_3.py: 一個傳統處理串列元素內容方式，與Python多重指定觀念的應用。

# %%
# ch6_3.py
james = [23, 19, 22, 31, 18]                # 定義james串列
# 傳統設計方式
game1 = james[0]
game2 = james[1]
game3 = james[2]
game4 = james[3]
game5 = james[4]
print("列印james各場次得分", game1, game2, game3, game4, game5)
# Python高手好的設計方式
game1, game2, game3, game4, game5 = james
print("列印james各場次得分", game1, game2, game3, game4, game5)

# %% [markdown]
# ### 6.1.3 串列切片(List Slice)
# ### 程式實例 ch6_4.py: 列出特定區間球員的得分子串列。

# %%
# ch6_4.py
james = [23, 19, 22, 31, 18]                # 定義james串列
print("列印james第1-3場得分", james[0:3])
print("列印james第2-4場得分", james[1:4])
print("列印james第1,3,5場得分", james[0:6:2])
# Out:
# 列印james第1-3場得分 [23, 19, 22]
# 列印james第2-4場得分 [19, 22, 31]
# 列印james第1,3,5場得分 [23, 22, 18]

# %% [markdown]
# ### 程式實例 ch6_5.py: 列出球隊前3名隊員，從索引1到最後球員與後3名隊員子串列

# %%
# ch6_5.py
warriors = ['Curry', 'Durant', 'Iquodala', 'Bell', 'Thompson']
first3 = warriors[:3]
print("前3名球員",first3)
n_to_last = warriors[1:]
print("球員索引1到最後",n_to_last)
last3 = warriors[-3:]
print("後3名球員",last3)
# Out:
# 前3名球員 ['Curry', 'Durant', 'Iquodala']
# 球員索引1到最後 ['Durant', 'Iquodala', 'Bell', 'Thompson']
# 後3名球員 ['Iquodala', 'Bell', 'Thompson']

# %% [markdown]
# ### 6.1.4 串列索引值是-1
# ### 程式實例 ch6_6.py: 串列索引值是-1的應用，由下列執行結果可以得到列出了各串列的最後一個元素了。

# %%
# ch6_6.py
warriors = ['Curry', 'Durant', 'Iquodala', 'Bell', 'Thompson']
print("最後一名球員",warriors[-1])
james = [23, 19, 22, 31, 18]
print("最後一場得分",james[-1])
mixs = [9, 20.5, 'DeepStone']
print("最後一筆元素",mixs[-1])

# %% [markdown]
# ### 程式實例 ch6_7.py: 使用負索引列出warriors 串列內容。

# %%
# ch6_7.py
warriors = ['Curry', 'Durant', 'Iquodala', 'Bell', 'Thompson']
print(warriors[-1],warriors[-2],warriors[-3],warriors[-4],warriors[-5])

# %% [markdown]
# ### 6.1.5 串列統計資料，最大值max()、最小值min()、總和sum()
# ### 程式實例 ch6_8.py: 計算james球員5場的最多得分、最少得分和5場的得分總計。

# %%
# ch6_8.py
james = [23, 19, 22, 31, 18]                # 定義james的5場比賽得分
print("最高得分 = ", max(james))
print("最低得分 = ", min(james))
print("得分總計 = ", sum(james))
# Out:
# 最高得分 =  31
# 最低得分 =  18
# 得分總計 =  113

# %% [markdown]
# ### 程式實例 ch6_9.py: 重新設計ch6_8.py，但是使用含字串元素的james串列。

# %%
# ch6_9.py
James = ['Lebron James', 23, 19, 22, 31, 18] # 定義james的5場比賽得分
print("最高得分 = ", max(James[1:6]))
print("最低得分 = ", min(James[1:6]))
print("得分總計 = ", sum(James[1:6]))

# %% [markdown]
# ### 6.1.6 串列個數 len()
# ### 程式實例 ch6_10.py: 重新設計ch6_8.py，獲得場次數據。

# %%
# ch6_10.py
james = [23, 19, 22, 31, 18]        # 定義james的5場比賽得分
games = len(james)                  # 獲得場次數據    
print("經過 %d 場比賽最高得分 = " % games, max(james))
print("經過 %d 場比賽最低得分 = " % games, min(james))
print("經過 %d 場比賽得分總計 = " % games, sum(james))
# Out:
# 經過 5 場比賽最高得分 =  31
# 經過 5 場比賽最低得分 =  18
# 經過 5 場比賽得分總計 =  113

# %% [markdown]
# ### 6.1.7 更改串列元素的內容
# ### 程式實例 ch6_11.py: 修改james第5場必賽分數。

# %%
# ch6_11.py
james = [23, 19, 22, 31, 18]        # 定義james的5場比賽得分
print("舊的James比賽分數", james)
james[4] = 28
print("新的James比賽分數", james)
# Out:
# 舊的James比賽分數 [23, 19, 22, 31, 18]
# 新的James比賽分數 [23, 19, 22, 31, 28]

# %% [markdown]
# 1. 假設班上10位同學的數學成績是90, 80, 88, 84, 85, 87, 88, 89, 90, 100，請建立一個score串列來儲存學生成績。
# 2. 請幫第一位同學(索引值0)的同學加10分    score[0]=score[0]+10
# 3. 請幫最後一位同學(索引值-1)的同學減10分
# 4. 印出最後的score成績。

# %% [markdown]
# ### 程式實例 ch6_12.py: 一家汽車經銷商原本可以銷售Toyota, Nissan, Honda，現在Nissan銷售權被回收，改成銷售Ford，可用下列方是設計銷售品牌。

# %%
# ch6_12.py
cars = ['Toyota', 'Nissan', 'Honda']
print("舊汽車銷售品牌", cars)
cars[1] = 'Ford'           # 更改第二筆元素內容
print("新汽車銷售品牌", cars)
# Out:
# 舊汽車銷售品牌 ['Toyota', 'Nissan', 'Honda']
# 新汽車銷售品牌 ['Toyota', 'Ford', 'Honda']

# %% [markdown]
# ### 6.1.8 串列的相加
# ### 程式實例 ch6_13.py: 一家汽車經銷商原本可以銷售Toyota, Nissan, Honda，現在併購一家銷售Audi, BMW的經銷商，可用下列方式設計銷售品牌。

# %%
# ch6_13.py
cars1 = ['Toyota', 'Nissan', 'Honda']
print("舊汽車銷售品牌", cars1)
cars2 = ['Audi', 'BMW']
cars1 += cars2
print("新汽車銷售品牌", cars1)

# %% [markdown]
# ### 程式實例 ch6_14.py: 整數串列相加的實例。

# %%
# ch6_14.py
num1 = [1, 3, 5]
num2 = [2, 4, 6]
num3 = num1 + num2           # 字串為主的串列相加
print(num3)
# Out:
# [1, 3, 5, 2, 4, 6]

# %% [markdown]
# ### 6.1.9 串列乘以一個數字
# ### 程式實例 ch6_15.py: 將串列乘以數字的應用

# %%
# ch6_15.py
cars = ['toyota', 'nissan', 'honda']
nums = [1, 3, 5]
carslist = cars * 3           # 串列乘以數字
print(carslist)
numslist = nums * 5           # 串列乘以數字
print(numslist)
# Out:
# ['toyota', 'nissan', 'honda', 'toyota', 'nissan', 'honda', 'toyota', 'nissan', 'honda']
# [1, 3, 5, 1, 3, 5, 1, 3, 5, 1, 3, 5, 1, 3, 5]

# %% [markdown]
# ### 6.1.10 串列元素的加法運作
# ### 程式實例 ch6_16.py: 建立Lebron James和Levin Love 在比賽的得分傳列，然後利用串列元素加法運作，列出2個人在第四場比賽的得分總和。

# %%
# ch6_16.py
James = ['Lebron James',23, 19, 22, 31, 18] # 定義James串列
Love = ['Kevin Love',20, 18, 30, 22, 15]    # 定義Love串列
game3 = James[4] + Love[4]
LKgame = James[0] + ' 和 ' +  Love[0] + '第四場總得分 = ' 
print(LKgame, game3)

# %% [markdown]
# ### 6.1.11 刪除串列元素
# ### 程式實例 ch6_17.py: 如果NBA勇士隊主將陣容有5名，其中一名隊員Bell離隊了，可用下列方式設計。

# %%
# ch6_17.py
warriors = ['Curry', 'Durant', 'Iquodala', 'Bell', 'Thompson']
print("2018年初NBA勇士隊主將陣容", warriors)
del warriors[3]                 # 不明原因離隊
print("2018年末NBA勇士隊主將陣容", warriors)

# %% [markdown]
# ### 程式實例 ch6_18.py: 刪除串列元素的應用

# %%
# ch6_18.py
nums1 = [1, 3, 5]
print("刪除nums1串列索引1元素前   = ",nums1)
del nums1[1]
print("刪除nums1串列索引1元素後   = ",nums1)
nums2 = [1, 2, 3, 4, 5, 6]
print("刪除nums2串列索引[0:2]前   = ",nums2)
del nums2[0:2]
print("刪除nums2串列索引[0:2]後   = ",nums2)
nums3 = [1, 2, 3, 4, 5, 6]
print("刪除nums3串列索引[0:6:2]前 = ",nums3)
del nums3[0:6:2]
print("刪除nums3串列索引[0:6:2]後 = ",nums3)

# %% [markdown]
# ### 6.1.12 串列為空字串的判斷
# ### 程式實例 ch6_19.py: 刪除串列元素的應用，這個程式基本上會用len()函數判斷串列內是否有元素資料，如果有則刪除所引為0的元素，如果沒有則列出串列內沒有元素了。

# %%
# ch6_19.py
cars = ['Toyota', 'Nissan', 'Honda']
print("cars串列長度是 = %d" %  len(cars))
if len(cars) != 0:
    del cars[0]
    print("刪除cars串列元素成功")
    print("cars串列長度是 = %d" % len(cars))
else:
    print("cars串列內沒有元素資料")
nums = []
print("nums串列長度是 = %d" % len(nums))
if len(nums) != 0:
    del nums[0]
    print("刪除nums串列元素成功")
else:
    print("nums串列內沒有元素資料")

# %% [markdown]
# ### 6.1.13 刪除串列
# ### 6.1.14 補充多重指定串列
# ## 6.2 Python簡單的物件導向觀念
# ### 6.2.1 更改字串大小寫 lower()/upper()/title()/swapcase()
# ### 程式實例 ch6_20.py: 將upper()和title應用在字串。

# %%
mystr = "Hello"
print(mystr[0])
print(mystr[1])
# Out:
# H
# e

# %%
# ch6_20.py
cars = ['bmw', 'benz', 'audi']     
carF = "我開的第一部車是 " + cars[1].title( )
carN = "我現在開的車子是 " + cars[0].upper( )
print(carF)
print(carN)
# Out:
# 我開的第一部車是 Benz
# 我現在開的車子是 BMW

# %%
# Out:
# Help on built-in function title:
#
# title() method of builtins.str instance
#     Return a version of the string where each word is titlecased.
#
#     More specifically, words start with uppercased characters and all remaining
#     cased characters have lower case.

# %% [markdown]
# ### 6.1.3 刪除空白自原rstrip()/lstrip()/strip()
# ### 程式實例 ch6_21.py: 刪除開始端與結尾端多餘空白的應用。

# %%
# ch6_21.py
strN = " DeepStone "
strL = strN.lstrip( )       # 刪除字串左邊多餘空白
strR = strN.rstrip( )       # 刪除字串右邊多餘空白
strB = strN.lstrip( )       # 先刪除字串左邊多餘空白
strB = strB.rstrip( )       # 再刪除字串右邊多餘空白
strO = strN.strip( )        # 一次刪除頭尾端多餘空白
print("/%s/" % strN)
print("/%s/" % strL)
print("/%s/" % strR)
print("/%s/" % strB)
print("/%s/" % strO)

# %% [markdown]
# ### 程式實例 ch6_22.py: 沒有使用strip()與有使用strip()方法處理讀取字串的觀察。

# %%
# ch6_22.py
string = input("請輸入名字 : ")
print("/%s/" % string)
string = input("請輸入名字 : ")
print("/%s/" % string.strip())

# %% [markdown]
# ### 程式實例 ch6_22_1.py: 活用Python的應用。

# %%
# ch6_22_1.py
string = input("請輸入英文名字 : ")
print("/%s/" % string)
string = input("請輸入英文名字 : ").strip()
print("/%s/" % string)
string = input("請輸入英文名字 : ").strip().title()
print("/%s/" % string)

# %% [markdown]
# ### 6.2.3 格式化字串位置center()/ljust()/rjust()/zfill()
# ### 程式實例 ch6_23.py: 格式化字串位置的應用

# %%
# ch6_23.py
title = "Ming-Chi Institute of Technology"
print("/%s/" % title.center(50))
dt = "Department of ME"
print("/%s/" % dt.ljust(50))
site = "JK Hung"
print("/%s/" % site.rjust(50))
print("/%s/" % title.zfill(50))

# %% [markdown]
# ### 6.2.4  islower()/isupper()/isdigit()/isalpha()
# ### 6.2.5 dir()獲得系統內建物件的方法
# ## 6.3 獲得串列的方法
# ## 6.4 增加與刪除串列元素
# ### 6.4.1 在串列末端增加元素append()
# ### 程式實例 ch6_24.py: 先建立一個空串列，然後分別使用append()增加3比元素內容。

# %%
# ch6_24.py
cars = []     
print("目前串列內容 = ",cars)
cars.append('Honda')
print("目前串列內容 = ",cars)
cars.append('Toyota')
print("目前串列內容 = ",cars)
cars.append('Ford')
print("目前串列內容 = ",cars)

# %% [markdown]
# ### 6.4.2 插入串列元素insert()
# ### 程式實例 ch6_25.py: 使用insert()插入串列元素的應用

# %%
# ch6_25.py
cars = ['Honda','Toyota','Ford']     
print("目前串列內容 = ",cars)
print("在索引1位置插入Nissan")
cars.insert(1,'Nissan')
print("新的串列內容 = ",cars)
print("在索引0位置插入BMW")
cars.insert(0,'BMW')
print("最新串列內容 = ",cars)

# %% [markdown]
# ### 6.4.3 刪除串列元素pop()
# ### 程式實例 ch6_26.py: 使用pop()刪除串列元素的應用，這個程式第5行未指明刪除的索引值，所以刪除了最後一個元素。程式第9行則是指名刪除索引為1位置的元素。

# %%
# ch6_26.py
cars = ['Honda','Toyota','Ford','BMW']     
print("目前串列內容 = ",cars)
print("使用pop( )刪除串列元素")
popped_car = cars.pop( )          # 刪除串列末端值
print("所刪除的串列內容是 : ", popped_car)
print("新的串列內容 = ",cars)
print("使用pop(1)刪除串列元素")
popped_car = cars.pop(1)          # 刪除串列索引為1的值
print("所刪除的串列內容是 : ", popped_car)
print("新的串列內容 = ",cars)

# %% [markdown]
# ### 6.4.4 刪除指定的元素remove()
# ### 程式實例 ch6_27.py: 刪除串列中第一次出現的元素bmw，這個串列有2筆bmw字串，最後只刪除索引為1位置的bmw字串。

# %%
# ch6_27.py
cars = ['Honda','bmw','Toyota','Ford','bmw']     
print("目前串列內容 = ",cars)
print("使用remove( )刪除串列元素")
expensive = 'bmw'
cars.remove(expensive)            # 刪除第一次出現的元素bmw
print("所刪除的內容是: " + expensive.upper( ) + " 因為太貴了" )
print("新的串列內容",cars)

# %% [markdown]
# ## 6.5 串列的排序
# ### 6.5.1 顛倒排序 reverse()
# ### 程式實例 ch6_28.py:使用2種方式執行顛倒排序串列元素。

# %%
# ch6_28.py
cars = ['Honda','bmw','Toyota','Ford','bmw']     
print("目前串列內容 = ",cars)
# 直接列印cars[::-1]顛倒排序,不更改串列內容
print("列印使用[::-1]顛倒排序\n", cars[::-1])
# 更改串列內容
print("使用reverse( )顛倒排序串列元素")
cars.reverse( )            # 顛倒排序串列
print("新的串列內容 = ",cars)

# %% [markdown]
# ### 6.5.2 sort()排序
# ### 程式實例 ch6_29.py: 數字與英文字串元素排序的應用。

# %%
# ch6_29.py
cars = ['honda','bmw','toyota','ford']     
print("目前串列內容 = ",cars)
print("使用sort( )由小排到大")
cars.sort( )            
print("排序串列結果 = ",cars)
nums = [5, 3, 9, 2]
print("目前串列內容 = ",nums)
print("使用sort( )由小排到大")
nums.sort( )            
print("排序串列結果 = ",nums)

# %% [markdown]
# ### 程式實例 ch6_30.py: 重新設計ch6_29.py，將串列元素由大排到小。

# %%
# ch6_30.py
cars = ['honda','bmw','toyota','ford']     
print("目前串列內容 = ",cars)
print("使用sort( )由大排到小")
cars.sort(reverse=True)            
print("排序串列結果 = ",cars)
nums = [5, 3, 9, 2]
print("目前串列內容 = ",nums)
print("使用sort( )由大排到小")
nums.sort(reverse=True)            
print("排序串列結果 = ",nums)

# %% [markdown]
# ### 6.5.3 sorted()排序
# ### 程式實例 ch6_31.py: sorted()排序的應用，這個程式使用car_sorted新串列儲存car串列的排序結果，同時使用num_sorted新串列儲存num串列排序結果。

# %%
# ch6_31.py
cars = ['honda','bmw','toyota','ford']     
print("目前串列car內容 = ",cars)
print("使用sorted( )由小排到大")
cars_sorted = sorted(cars)            
print("排序串列結果 = ",cars_sorted)
print("原先串列car內容 = ",cars)
nums = [5, 3, 9, 2]     
print("目前串列num內容 = ",nums)
print("使用sorted( )由小排到大")
nums_sorted = sorted(nums)            
print("排序串列結果 = ",nums_sorted)
print("原先串列num內容 = ",nums)

# %% [markdown]
# ### 程式實例 ch6_32.py: 重新設計ch6_31.py，將串列由大排到小。

# %%
# ch6_32.py
cars = ['honda','bmw','toyota','ford']     
print("目前串列car內容 = ",cars)
print("使用sorted( )由大排到小")
cars_sorted = sorted(cars,reverse=True)            
print("排序串列結果    = ",cars_sorted)
print("原先串列car內容 = ",cars)
nums = [5, 3, 9, 2]     
print("目前串列num內容 = ",nums)
print("使用sorted( )由大排到小")
nums_sorted = sorted(nums,reverse=True)            
print("排序串列結果    = ",nums_sorted)
print("原先串列num內容 = ",nums)

# %% [markdown]
# ## 6.6 進階串列操作
# ### 6.6.1 index()
# ### 程式實例 ch6_33.py: 傳回搜尋索引值的應用。

# %%
# ch6_33.py
cars = ['toyota', 'nissan', 'honda']
search_str = 'nissan'
i = cars.index(search_str)
print("所搜尋元素 %s 第一次出現位置索引是 %d" % (search_str, i))
nums = [7, 12, 30, 12, 30, 9, 8]
search_val = 30
j = nums.index(search_val)
print("所搜尋元素 %s 第一次出現位置索引是 %d" % (search_val, j))

# %% [markdown]
# ### 程式實例 ch6_34.py:使用ch6_16.py的串列James，這個串列有Lebron James一系列比賽得分，由此串列請計算他在第幾場得最高分，同時列出所得分數。

# %%
# ch6_34.py
James = ['Lebron James',23, 19, 22, 31, 18] # 定義James串列
games = len(James)                          # 求元素數量
score_Max = max(James[1:games])             # 最高得分
i = James.index(score_Max)                  # 場次
print(James[0], "在第 %d 場得最高分 %d" % (i, score_Max))

# %% [markdown]
# ### 6.6.2 count()
# ### 程式實例 ch6_35.py: 傳回搜尋值出現的次數的應用。

# %%
# ch6_35.py
cars = ['toyota', 'nissan', 'honda']
search_str = 'nissan'
num1 = cars.count(search_str)
print("所搜尋元素 %s 出現 %d 次" % (search_str, num1))
nums = [7, 12, 30, 12, 30, 9, 8]
search_val = 30
num2 = nums.count(search_val)
print("所搜尋元素 %s 出現 %d 次" % (search_val, num2))

# %% [markdown]
# ## 6.7 串列內含串列
# ### 程式實例 ch6_36.py: 擴充ch6_34.py 先列出Lebron James個人資料再計算那一個場次得到最高分。程式第2行'SF'全名是Small Forward小前鋒。

# %%
# ch6_36.py
James = [['Lebron James','SF','12/30/84'],23,19,22,31,18] # 定義James串列
games = len(James)                                        # 求元素數量
score_Max = max(James[1:games])                           # 最高得分
i = James.index(score_Max)                                # 場次
name = James[0][0]
position = James[0][1]
born = James[0][2]
print("姓名     : ", name)
print("位置     : ", position)
print("出生日期 : ", born)
print("在第 %d 場得最高分 %d" % (i, score_Max))

# %% [markdown]
# ### 程式實例 ch6_37.py: 上述6_36.py的第6-8行是為了詳細解說，真正了解Python精神人，可以用下列一行取代這3行，用Python精神，重新設計ch6_36.py

# %%
# ch6_37.py
James = [['Lebron James','SF','12/30/84'],23,19,22,31,18] # 定義James串列
games = len(James)                                        # 求元素數量
score_Max = max(James[1:games])                           # 最高得分
i = James.index(score_Max)                                # 場次
name, position, born = James[0]
print("姓名     : ", name)
print("位置     : ", position)
print("出生日期 : ", born)
print("在第 %d 場得最高分 %d" % (i, score_Max))

# %% [markdown]
# ### 6.7.1 再談append()
# ### 程式實例 ch6_38.py: 使愈append()將串列插入另一串列的末端。

# %%
# ch6_38.py
cars1 = ['toyota', 'nissan', 'honda']
cars2 = ['ford', 'audi']
print("原先cars1串列內容 = ", cars1)
print("原先cars2串列內容 = ", cars2)
cars1.append(cars2)
print("執行append( )後串列cars1內容 = ", cars1)
print("執行append( )後串列cars2內容 = ", cars2)

# %% [markdown]
# ### 6.7.2 extend()
# ### 程式實例 ch6_39.py: 使用extend()方法取代ch6_38.py，並觀察執行結果。

# %%
# ch6_39.py
cars1 = ['toyota', 'nissan', 'honda']
cars2 = ['ford', 'audi']
print("原先cars1串列內容 = ", cars1)
print("原先cars2串列內容 = ", cars2)
cars1.extend(cars2)
print("執行extend( )後串列cars1內容 = ", cars1)
print("執行extend( )後串列cars2內容 = ", cars2)

# %% [markdown]
# ### 6.7.3 再看二維陣列
# ### 程式實例 ch6_40.py: 二維串列的成績系統總分計算。

# %%
# ch6_40.py
sc = [['洪錦魁', 80, 95, 88, 0],
      ['洪冰儒', 98, 97, 96, 0],
     ]
sc[0][4] = sum(sc[0][1:4])
sc[1][4] = sum(sc[1][1:4])
print(sc[0])
print(sc[1])

# %% [markdown]
# ## 6.8 串列的賦值與切片拷貝
# ### 6.8.1 串列賦值
# ### 程式實例 ch6_41.py: 列出我和朋友所喜歡的運動。

# %%
# ch6_41.py
mysports = ['basketball', 'baseball']
friendsports = mysports
print("我喜歡的運動     = ", mysports)
print("我朋友喜歡的運動 = ", friendsports)

# %% [markdown]
# ### 程式實例 ch6_42.py:繼續使用ch6_41.py，加入美式足球football當作喜歡的運動，我的朋友想加入傳統足球soccer當作喜歡的運動，同時列出執行結果。

# %%
# ch6_42.py
mysports = ['basketball', 'baseball']
friendsports = mysports
print("我喜歡的運動     = ", mysports)
print("我朋友喜歡的運動 = ", friendsports)
mysports.append('football')
friendsports.append('soccer')
print("我喜歡的最新運動     = ", mysports)
print("我朋友喜歡的最新運動 = ", friendsports)

# %% [markdown]
# ### 6.8.2 位址的觀念
# ### 程式實例 ch6_43.py: 重新設計ch6_42.py，增加列出串列變數的位址。

# %%
# ch6_43.py
mysports = ['basketball', 'baseball']
friendsports = mysports
print("列出mysports位址     = ", id(mysports))
print("列出friendsports位址 = ", id(friendsports))
print("我喜歡的運動     = ", mysports)
print("我朋友喜歡的運動 = ", friendsports)
mysports.append('football')
friendsports.append('soccer')
print(" -- 新增運動項目後 -- ")
print("列出mysports位址     = ", id(mysports))
print("列出friendsports位址 = ", id(friendsports))
print("我喜歡的最新運動     = ", mysports)
print("我朋友喜歡的最新運動 = ", friendsports)

# %% [markdown]
# ### 6.8.3 串列的切片拷貝
# ### 程式實例 ch6_44.py: 使用拷貝方式，重新設計ch6_42.py。

# %%
# ch6_44.py
mysports = ['basketball', 'baseball']
friendsports = mysports[:]
print("列出mysports位址     = ", id(mysports))
print("列出friendsports位址 = ", id(friendsports))
print("我喜歡的運動     = ", mysports)
print("我朋友喜歡的運動 = ", friendsports)
mysports.append('football')
friendsports.append('soccer')
print(" -- 新增運動項目後 -- ")
print("列出mysports位址     = ", id(mysports))
print("列出friendsports位址 = ", id(friendsports))
print("我喜歡的最新運動     = ", mysports)
print("我朋友喜歡的最新運動 = ", friendsports)

# %% [markdown]
# ### 6.8.4 淺拷貝(copy)與深拷貝(deepcopy)
# ## 6.9 再談字串
# ### 6.9.1 字串的索引
# ### 程式實例 ch6_45.py: 使用正值與負值的索引列出字串元素內容

# %%
# ch6_45.py
string = "Python"
# 正值索引
print(" string[0] = ", string[0],
      "\n string[1] = ", string[1],
      "\n string[2] = ", string[2],
      "\n string[3] = ", string[3],
      "\n string[4] = ", string[4],
      "\n string[5] = ", string[5])
# 負值索引
print(" string[-1] = ", string[-1],
      "\n string[-2] = ", string[-2],
      "\n string[-3] = ", string[-3],
      "\n string[-4] = ", string[-4],
      "\n string[-5] = ", string[-5],
      "\n string[-6] = ", string[-6])
# 多重指定觀念
s1, s2, s3, s4, s5, s6 = string
print("多重指定觀念的輸出測試 = ",s1,s2,s3,s4,s5,s6)

# %% [markdown]
# ### 6.9.2 字串切片
# ### 程式實例 ch6_46.py: 字串切片的應用

# %%
# ch6_46.py
string = "Deep Learning"                # 定義字串
print("列印string第0-2元素     = ", string[0:3])
print("列印string第1-3元素     = ", string[1:4])
print("列印string第1,3,5元素   = ", string[1:6:2])
print("列印string第1到最後元素 = ", string[1:])
print("列印string前3元素       = ", string[0:3])
print("列印string後3元素       = ", string[-3:])

# %% [markdown]
# ### 6.9.3 函數或方法
# ### 程式實例 ch6_47.py: 將函數len()、max()、min()應用在字串。

# %%
# ch6_47.py
string = "Deep Learning"                # 定義字串
strlen = len(string)
print("字串長度", strlen)
maxstr = max(string)
print("字串最大的unicode碼值和字元", ord(maxstr), maxstr)
minstr = min(string)
print("字串最小的unicode碼值和字元", ord(minstr), minstr)

# %% [markdown]
# ### 6.9.4 將字串轉成串列
# ### 6.9.5 切片賦值的應用
# ### 6.9.6 使用split()分割字串
# ### 程式實例 ch6_48.py: 將2種不同類型的字串轉成串列，其中str1使用空格當作分隔符號，str2使用'\'當作分格符號(因為這是逸出自元，所以使用\\)，同時這個程式會列出這2個串列的元素數量。

# %%
# ch6_48.py
str1 = "Silicon Stone Education"
str2 = "D:\Python\ch6"

sList1 = str1.split()                       # 字串轉成串列
sList2 = str2.split("\\")                   # 字串轉成串列
print(str1, " 串列內容是 ", sList1)         # 列印串列
print(str1, " 串列字數是 ", len(sList1))    # 列印字數
print(str2, " 串列內容是 ", sList2)         # 列印串列
print(str2, " 串列字數是 ", len(sList2))    # 列印字數

# %% [markdown]
# ### 6.9.7 串列元素的組合join()
# ### 程式實例 ch6_49.py: 將串列內容連接。

# %%
# ch6_49.py
path = ['D:','ch6','ch6_49.py']
connect = '\\'                   # 路徑分隔字元
print(connect.join(path))
connect = '*'                   # 普通字元
print(connect.join(path))

# %% [markdown]
# ### 6.9.8 字串的其他方法
# ### 程式實例 ch6_50.py: 列出字串"CIA"是不是啟始或結束字串，以及出現次數。最後這個程式會將Linda字串用Lxx字串取代，這是一種保護情報員名字不外洩的方法。

# %%
# ch6_50.py
msg = '''CIA Mark told CIA Linda that the secret USB had given to CIA Peter'''
print("字串開頭是CIA: ", msg.startswith("CIA"))
print("字串結尾是CIA: ", msg.endswith("CIA"))
print("CIA出現的次數: ",msg.count("CIA"))
msg = msg.replace('Linda','Lxx')
print("新的msg內容 : ", msg)

# %% [markdown]
# ## 6.10 in 和 not in 運算式
# ### 程式實例 ch6_51.py: 請輸入字元，這個程式會判斷字元是否再字串內。

# %%
# ch6_51.py
password = 'deepstone'
ch = input("請輸入字元 = ")
print("in運算式")
if ch in password:
    print("輸入字元在密碼中")
else:
    print("輸入字元不在密碼中")
    
print("not in運算式")
if ch not in password:
    print("輸入字元不在密碼中")
else:
    print("輸入字元在密碼中")

# %% [markdown]
# ### 程式實例 ch6_52.py: 這個程式基本上會要求輸入一個水果，如果串列內目前沒有這個水果，救將輸入的水果加入串列內。

# %%
# ch6_52.py
fruits = ['apple', 'banana', 'watermelon']
fruit = input("請輸入水果 = ")
if fruit in fruits:
    print("這個水果已經有了")
else:
    fruits.append(fruit)
    print("謝謝提醒已經加入水果清單: ", fruits)

# %% [markdown]
# ## 6.11 is 或 is not 運算式
# ### 6.11.1 整體變數在記憶體位址的觀察
# ### 程式實例 ch6_53.py: 整數變數在記憶體位址的觀察，這個程式比較特別的是，程式執行初，變數x和y值是10，所以可以看到經過id()函數後，彼此有相同的記憶體位址。變數z和r由於值與x和y不相同，所有有不同的記憶體位址，經過第9行運算後r的值變為10，最後得到x、y和r不僅值相同同時也指向相同的記憶體位址。

# %%
# ch6_53.py
x = 10
y = 10
z = 15
r = 20
print("x = %d, y = %d, z = %d, r = %d" % (x, y, z, r))
print("x位址 = %d, y位址 = %d, z位址 = %d, r位址 = %d"
      % (id(x), id(y), id(z), id(r)))
r = x                               # r的值將變為10
print("x = %d, y = %d, z = %d, r = %d" % (x, y, z, r))
print("x位址 = %d, y位址 = %d, z位址 = %d, r位址 = %d"
      % (id(x), id(y), id(z), id(r)))

# %% [markdown]
# ### 6.11.2 將is和is not運算式應用在整體變數
# ### 程式實例 ch6_54.py: is 和 is not 運算式應用在整體變數

# %%
# ch6_54.py
x = 10
y = 10
z = 15
r = z - 5
boolean_value = x is y
print("x位址 = %d, y位址 = %d" % (id(x), id(y)))
print("x = %d, y = %d, " % (x, y), boolean_value)

boolean_value = x is z
print("x位址 = %d, z位址 = %d" % (id(x), id(z)))
print("x = %d, z = %d, " % (x, z), boolean_value)

boolean_value = x is r
print("x位址 = %d, r位址 = %d" % (id(x), id(r)))
print("x = %d, r = %d, " % (x, r), boolean_value)

boolean_value = x is not y
print("x位址 = %d, y位址 = %d" % (id(x), id(y)))
print("x = %d, y = %d, " % (x, y), boolean_value)

boolean_value = x is not z
print("x位址 = %d, z位址 = %d" % (id(x), id(z)))
print("x = %d, z = %d, " % (x, z), boolean_value)

boolean_value = x is not r
print("x位址 = %d, r位址 = %d" % (id(x), id(r)))
print("x = %d, r = %d, " % (x, r), boolean_value)

# %% [markdown]
# ### 6.11.3 將is和is not 運算式影用在串列變數
# ### 程式實例 ch6_55.py: 這個範例所使用的3個串列內容均是相同，但是mysports和sports1所指位址相同所以會被視為相同物件，sports2則指向不同位址所以會被視為不同物件，在使用is指令測試時，不同位址的串列會被視為不同的串列。

# %%
# ch6_55.py
mysports = ['basketball', 'baseball']
sports1 = mysports          # 賦值
sports2 = mysports[:]       # 切片拷貝新串列
print("我喜歡的運動 = ", mysports, "位址是 = ", id(mysports))
print("運動 1       = ", sports1,  "位址是 = ", id(sports1))
print("運動 2       = ", sports2,  "位址是 = ", id(sports2))
boolean_value = mysports is sports1
print("我喜歡的運動 is 運動 1     = ", boolean_value)

boolean_value = mysports is sports2
print("我喜歡的運動 is 運動 2     = ", boolean_value)

boolean_value = mysports is not sports1
print("我喜歡的運動 is not 運動 1 = ", boolean_value)

boolean_value = mysports is not sports2
print("我喜歡的運動 is not 運動 2 = ", boolean_value)

# %% [markdown]
# ## 6.12 enumerate 物件
# ### 程式實例 ch6_56.py: 將串列資料轉成enumerate物件，同時列出此物件的類型。

# %%
# ch6_56.py
drinks = ["coffee", "tea", "wine"]
enumerate_drinks = enumerate(drinks)        # 數值初始是0
print(enumerate_drinks)                     # 傳回enumerate物件所在記憶體
print("下列是輸出enumerate物件類型")
print(type(enumerate_drinks))               # 列出物件類型

# %% [markdown]
# ### 程式實例 ch6_57.py: 將串列資料轉成enumerate物件，再將enumerate物件轉成自串列的實例，start索引啟始值分別為0和10。

# %%
# ch6_57.py
drinks = ["coffee", "tea", "wine"]
enumerate_drinks = enumerate(drinks)                # 數值初始是0
print("轉成串列輸出, 初始索引值是 0 = ", list(enumerate_drinks))

enumerate_drinks = enumerate(drinks, start = 10)    # 數值初始是10
print("轉成串列輸出, 初始索引值是10 = ", list(enumerate_drinks))

# %% [markdown]
# ## 6.13 專題
# ### 6.13.1 製作大型的串列資料
# ### 程式實例 ch6_58.py: 設計一個帳號管理系統，這個程式分成2個部分，第一個部分是建立帳號，讀者的輸入將會存在accounts串列。第2個部分是要求輸入帳號，如果輸入正確會輸出"歡迎進入深石系統"，如果輸入錯誤會輸出"帳號錯誤"

# %%
# ch6_58.py
accounts = []                       # 建立空帳號串列
account = input("請輸入新帳號 = ")
accounts.append(account)            # 將輸入加入帳號串列

print("深石公司系統")
ac = input("請輸入帳號 = ")
if ac in accounts:
    print("歡迎進入深石系統")
else:
    print("帳號錯誤")
